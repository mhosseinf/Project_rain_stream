# %%
from pathlib import Path
import pandas as pd

# %%
# Specify the file path
rain = '../Resources/rain.csv'

# Use pandas to read the CSV file
rain_df = pd.read_csv(rain)
# Drop columns 15 and onward
rain_df = rain_df.drop(rain_df.columns[31:], axis=1)

# %%
rain_df
# Out:
#            Date  509704  Quality  509573  Quality.1  509398  Quality.2  \
# 0     1/07/2023     0.0       99     0.0         99     0.0         99
# 1     2/07/2023     0.0       99     0.0         99     0.0         99
# 2     3/07/2023    19.2       99    14.0         99    14.4         99
# 3     4/07/2023     3.2       99     5.8         99     3.6         99
# 4     5/07/2023     6.4       99    10.2         99     4.2         99
# ..          ...     ...      ...     ...        ...     ...        ...
# 122  31/10/2023     0.0       99     0.0         99     0.0         99
# 123   1/11/2023     0.0       99     0.0         99     0.0         99
# 124   2/11/2023     0.0       99     0.0         99     0.0         99
# 125   3/11/2023     0.0       99     0.0         99     0.0         99
# 126   4/11/2023     0.0       99     0.0         99     0.0         99
#
#      509452  Quality.3  509417  ...  W0034613  Quality.10  509703  Quality.11  \
# ...

# %%
# Specify the file path
stream = '../Resources/streamflow.csv'

# Use pandas to read the CSV file
stream_df = pd.read_csv(stream)
# Drop columns 15 and onward
stream_df = stream_df.drop(stream_df.columns[15:], axis=1)

# %%
stream_df
# Out:
#           Date  616042  Quality  616043  Quality.1  616047  Quality.2  616015  \
# 0    1/07/2023  10.162       99  10.120         99  10.086         99  10.052
# 1    2/07/2023  10.158       99  10.116         99  10.082         99  10.051
# 2    3/07/2023  10.254       99  10.185         99  10.186         99  10.115
# 3    4/07/2023  10.333       99  10.248         99  10.191         99  10.104
# 4    5/07/2023  10.271       99  10.200         99  10.194         99  10.093
# ..         ...     ...      ...     ...        ...     ...        ...     ...
# 123  1/11/2023  10.079       99  10.091         99  10.044         99  10.011
# 124  2/11/2023  10.078       99  10.089         99  10.041         99  10.008
# 125  3/11/2023  10.077       99  10.090         99  10.039         99  10.006
# 126  4/11/2023  10.083       99  10.089         99  10.038         99  10.002
# 127  5/11/2023  10.077       99  10.089         99  10.039         99   9.999
#
# ...
